# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniel-online/Jupyter/blob/main/C%C3%B3pia_de_AgregadorExcel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install xlwt
# !pip install xlsxwriter
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0/100.0 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 2.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import xlwt as xlwt
from pandas.io.excel import ExcelWriter
import openpyxl as opn
import csv
import datetime as dt
from xlsxwriter import workbook

# %%
# CSV_TO_EXCEL= ExcelWriter('df_IO_inventory')
# criar o dataframe com base no csv
df_IO_inventory = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Data-Agregador/IO_Inventory_Data.csv", sep =";")

# transformar em excel
novoExcel = pd.ExcelWriter('/content/drive/MyDrive/Colab Notebooks/Excel/IO_Inventory_Data.xlsx', engine='xlsxwriter')
df_IO_inventory.to_excel(novoExcel, sheet_name= "IO_Inventory_Data", index= False )
novoExcel.save()
# Out:
# <ipython-input-3-26ce9bb7f927>:8: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   novoExcel.save()

# %%
display(novoExcel)
df_IO_inventory.head()
# Out:
#                     SKU     LOCATION      DATE SafetyStock_Qty  \
# 0  NO093 BIODIESEL B100  5012 BABRAS  20230701     203,3077239
# 1  NO093 BIODIESEL B100  5012 BABRAS  20230801     207,3172708
# 2  NO093 BIODIESEL B100  5012 BABRAS  20230901      253,108751
# 3  NO093 BIODIESEL B100  5012 BABRAS  20231001     288,9648426
# 4  NO093 BIODIESEL B100  5012 BABRAS  20231101     224,8817766
#
#   SafetyStock_Days CycleStock_Qty CycleStock_Days SafetyStock_Calc_Qty  \
# 0      2,254675543    90,23463106     1,000698901          203,3077239
# 1      2,269256512    91,94013638     1,006359733          207,3172708
# 2      2,277459784    112,0499272     1,008219598           253,108751
# 3      2,207424911    129,1370443     0,986487927          288,9648426
# 4      2,235607627    100,2641409     0,996751634          224,8817766
#
#   SafetyStock_Calc_Days PipelineStock_Calc_Qty
# 0           2,254675543            123,2907478
# 1           2,269256512            130,9920035
# ...

# %%
#processar location / separar o codigo numerico do nome da base
df_IO_inventory [['codLocation', 'descLocation']] = df_IO_inventory['LOCATION'].str.split(' ', 1, expand = True)
df_IO_inventory [['subgrupo', 'desc_subgrupo', 'num']] = df_IO_inventory['SKU'].str.split(' ', 2, expand = True)
      # 2 indica que queremos dividir em no máximo 2 partes
      # expand=True para criar colunas separadas para cada parte
# Out:
# <ipython-input-5-1703548ce4c8>:2: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df_IO_inventory [['codLocation', 'descLocation']] = df_IO_inventory['LOCATION'].str.split(' ', 1, expand = True)
# <ipython-input-5-1703548ce4c8>:3: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df_IO_inventory [['subgrupo', 'desc_subgrupo', 'num']] = df_IO_inventory['SKU'].str.split(' ', 2, expand = True)

# %%
df_IO_inventory.head()
# Out:
#                     SKU     LOCATION      DATE SafetyStock_Qty  \
# 0  NO093 BIODIESEL B100  5012 BABRAS  20230701     203,3077239
# 1  NO093 BIODIESEL B100  5012 BABRAS  20230801     207,3172708
# 2  NO093 BIODIESEL B100  5012 BABRAS  20230901      253,108751
# 3  NO093 BIODIESEL B100  5012 BABRAS  20231001     288,9648426
# 4  NO093 BIODIESEL B100  5012 BABRAS  20231101     224,8817766
#
#   SafetyStock_Days CycleStock_Qty CycleStock_Days SafetyStock_Calc_Qty  \
# 0      2,254675543    90,23463106     1,000698901          203,3077239
# 1      2,269256512    91,94013638     1,006359733          207,3172708
# 2      2,277459784    112,0499272     1,008219598           253,108751
# 3      2,207424911    129,1370443     0,986487927          288,9648426
# 4      2,235607627    100,2641409     0,996751634          224,8817766
#
#   SafetyStock_Calc_Days PipelineStock_Calc_Qty codLocation descLocation  \
# 0           2,254675543            123,2907478        5012       BABRAS
# ...

# %%
#devido a como o split() funciona, precisamos agrupar
#o tipo de combustivel e o nome de combustivel

#df_IO_inventory['desc_Subgrupo'] = df_IO_inventory['desc_subgrupo','num'].apply(lambda x: ''.join(x), axis = 1)
df_IO_inventory['desc_Subgrupo'] = df_IO_inventory['desc_subgrupo']+ " " + df_IO_inventory['num']

# %%
df_IO_inventory.head()
# Out:
#                     SKU     LOCATION      DATE SafetyStock_Qty  \
# 0  NO093 BIODIESEL B100  5012 BABRAS  20230701     203,3077239
# 1  NO093 BIODIESEL B100  5012 BABRAS  20230801     207,3172708
# 2  NO093 BIODIESEL B100  5012 BABRAS  20230901      253,108751
# 3  NO093 BIODIESEL B100  5012 BABRAS  20231001     288,9648426
# 4  NO093 BIODIESEL B100  5012 BABRAS  20231101     224,8817766
#
#   SafetyStock_Days CycleStock_Qty CycleStock_Days SafetyStock_Calc_Qty  \
# 0      2,254675543    90,23463106     1,000698901          203,3077239
# 1      2,269256512    91,94013638     1,006359733          207,3172708
# 2      2,277459784    112,0499272     1,008219598           253,108751
# 3      2,207424911    129,1370443     0,986487927          288,9648426
# 4      2,235607627    100,2641409     0,996751634          224,8817766
#
#   SafetyStock_Calc_Days PipelineStock_Calc_Qty codLocation descLocation  \
# 0           2,254675543            123,2907478        5012       BABRAS
# ...

# %%
df_IO_inventory.loc[['SafetyStock_Qty', 'CycleStock_Qty']== 100000, '']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df_IO_inventory['DATE'] = df_IO_inventory.apply(lambda x: datetime.datetime.strptime(str(x), '%Y%m%d'))

Excel_mes_Tratado = pd.ExcelWriter('meses_excel.xlsx', engine = 'xlsxwriter')

df_IO_inventory.to_excel(Excel_mes_Tratado, sheet_name = 'mes-Tratado' index=False)

workbook = Excel_mes_Tratado.book
worksheet = workbook[]

# %%
#processar data /  corrigir e registrar em formato 00/00/0000
planilhaFiltrada = opn.load_workbook('/content/drive/MyDrive/Colab Notebooks/Excel/IO_Inventory_Data.xlsx')
planilhaGrupo = planilhaFiltrada.sheetnames
planilha = planilhaFiltrada[planilhaGrupo[0]]
colunas = planilha.max_row

# Definir o formato de data para a coluna 'Data' (por exemplo, 'dd/mm/yyyy')
date_format = opn.styles.NamedStyle( name ='date_style', number_format = 'DD/MM/YYYY')
workbook.add_named_style(date_format)

#----
novoExcel.save()

# %%
#processar sku / obter grupo (alfanumerico) e subgrupo (nome)m

# %%
#Abrir o arquivo bom_io
#filtrar subgroup_filho procurando os grupos pai

# %%
#Abrir o arquivo "export_io"
df_export-io = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Data-Agregador/Export_IO_AGREGADO.csv",  sep=',')
#transformar em excel
df_export-io.to_excel(Export_IO_AGREGADO, sheet_name = 'Export_IO_AGREGADO' index=False)
#converter valores de US para br

#usar o codigo alafanumerio do subgrupo

# filtrar o "element 1"

#usar codigo da base

#filtrar "elemtent 2"

# %%
#extrair coluna de mes de analise
#usar o uaf4
#criar variavel com o valor

# %%
# extrair volume do export io apos a filtragem
# produto A =  produto B * percentual
# decalrar essas variaveis como literais

# %%
# >abrir dias_uteis_mes
#transformar em excel
# extrair qtd_dias_uteis
#periodo =  mes e analise

# %%
# NDE Meta Operacional = [Volume do SS + (volume Ciclo/2) ] / (EV mensal / qtde dias úteis)
